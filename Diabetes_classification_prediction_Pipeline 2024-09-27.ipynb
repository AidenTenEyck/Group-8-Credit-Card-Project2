# %%
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt

# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/gasho/OneDrive/Desktop/MLAI/Group-8-Credit-Card-Project1/diabetes_prediction_dataset.csv")
data.head(20)
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  80.0             0              1           never  25.19
# 1   Female  54.0             0              0         No Info  27.32
# 2     Male  28.0             0              0           never  27.32
# 3   Female  36.0             0              0         current  23.45
# 4     Male  76.0             1              1         current  20.14
# 5   Female  20.0             0              0           never  27.32
# 6   Female  44.0             0              0           never  19.31
# 7   Female  79.0             0              0         No Info  23.86
# 8     Male  42.0             0              0           never  33.64
# 9   Female  32.0             0              0           never  27.32
# 10  Female  53.0             0              0           never  27.32
# 11  Female  54.0             0              0          former  54.70
# 12  Female  78.0             0              0          former  36.05
# ...

# %%
profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)

profile.to_widgets()

# Display the report in Jupyter Notebook
profile.to_notebook_iframe()

# Optionally, save the report
profile.to_file("your_report.html")
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 1760  Female  80.0             0              0         No Info  27.32
# 1778  Female  80.0             0              0         No Info  27.32
# 1677  Female  80.0             0              0         No Info  27.32
# 1680  Female  80.0             0              0         No Info  27.32
# 1683  Female  80.0             0              0         No Info  27.32
# 1684  Female  80.0             0              0         No Info  27.32
# 1689  Female  80.0             0              0         No Info  27.32
# 1788  Female  80.0             0              0         No Info  27.32
# 1262  Female  52.0             0              0         No Info  27.32
# 1672  Female  80.0             0              0         No Info  27.32
#
#       HbA1c_level  blood_glucose_level  diabetes  # duplicates
# 1760          6.2                   90         0             9
# ...

# %%
import Util as p_utils

# %%
p_utils.model_evaluation(data,"diabetes","")
# Out:
# RandomForestClassifier  Report:
# Accuracy of RandomForestClassifier: 0.96992
# Train Model Score: 0.999
# Test Model Score: 0.970
# Balanced Train Accuracy Score: 0.9958909451686346
# Balanced Test Accuracy Score: 0.8394422675690805
# Test roc_auc_score 0.9647895068953236
# RandomForestClassifier  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     22850
#            1       0.96      0.68      0.80      2150
#
#     accuracy                           0.97     25000
#    macro avg       0.96      0.84      0.89     25000
# weighted avg       0.97      0.97      0.97     25000
#
# **********************************************************************
# LogisticRegression  Report:
# Accuracy of LogisticRegression: 0.95836
# Train Model Score: 0.961
# Test Model Score: 0.958
# Balanced Train Accuracy Score: 0.8117235090697421
# Balanced Test Accuracy Score: 0.8006742659406646
# ...

# %%
p_utils.model_evaluation(data,"diabetes","RandomUnderSampler")
# Out:
# RandomForestClassifier RandomUnderSampler Report:
# Accuracy of RandomForestClassifier: 0.90324
# Train Model Score: 1.000
# Test Model Score: 0.903
# Balanced Train Accuracy Score: 0.9996850393700787
# Balanced Test Accuracy Score: 0.9068286601190779
# Test roc_auc_score 0.9750903974352451
# RandomForestClassifier RandomUnderSampler Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94     22850
#            1       0.47      0.91      0.62      2150
#
#     accuracy                           0.90     25000
#    macro avg       0.73      0.91      0.78     25000
# weighted avg       0.95      0.90      0.92     25000
#
# **********************************************************************
# LogisticRegression RandomUnderSampler Report:
# Accuracy of LogisticRegression: 0.88692
# Train Model Score: 0.886
# Test Model Score: 0.887
# Balanced Train Accuracy Score: 0.8856692913385826
# ...

# %%
p_utils.model_evaluation(data,"diabetes","RandomOverSampler")
# Out:
# RandomForestClassifier RandomOverSampler Report:
# Accuracy of RandomForestClassifier: 0.96516
# Train Model Score: 0.999
# Test Model Score: 0.965
# Balanced Train Accuracy Score: 0.999497450837582
# Balanced Test Accuracy Score: 0.8469507913083303
# Test roc_auc_score 0.9654615948297798
# RandomForestClassifier RandomOverSampler Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     22850
#            1       0.87      0.70      0.78      2150
#
#     accuracy                           0.97     25000
#    macro avg       0.92      0.85      0.88     25000
# weighted avg       0.96      0.97      0.96     25000
#
# **********************************************************************
# LogisticRegression RandomOverSampler Report:
# Accuracy of LogisticRegression: 0.88688
# Train Model Score: 0.883
# Test Model Score: 0.887
# Balanced Train Accuracy Score: 0.8833211944646759
# ...

# %%
p_utils.model_evaluation(data,"diabetes","SMOTE")
# Out:
# RandomForestClassifier SMOTE Report:
# Accuracy of RandomForestClassifier: 0.9584
# Train Model Score: 1.000
# Test Model Score: 0.958
# Balanced Train Accuracy Score: 0.999606700655499
# Balanced Test Accuracy Score: 0.8615815989008193
# Test roc_auc_score 0.9670861330212203
# RandomForestClassifier SMOTE Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     22850
#            1       0.77      0.74      0.75      2150
#
#     accuracy                           0.96     25000
#    macro avg       0.87      0.86      0.87     25000
# weighted avg       0.96      0.96      0.96     25000
#
# **********************************************************************
# LogisticRegression SMOTE Report:
# Accuracy of LogisticRegression: 0.88276
# Train Model Score: 0.889
# Test Model Score: 0.883
# Balanced Train Accuracy Score: 0.8885142024763292
# Balanced Test Accuracy Score: 0.8631810086000713
# ...

# %%
import Model_features as p_utils1

# %%
p_utils1.model_features(data,"diabetes")
# Out:
# k: 1, Train/Test Score: 0.999/0.949
# k: 3, Train/Test Score: 0.974/0.959
# k: 5, Train/Test Score: 0.970/0.960
# k: 7, Train/Test Score: 0.968/0.961
# k: 9, Train/Test Score: 0.967/0.961
# k: 11, Train/Test Score: 0.966/0.961
# k: 13, Train/Test Score: 0.965/0.961
# k: 15, Train/Test Score: 0.965/0.961
# k: 17, Train/Test Score: 0.965/0.961
# k: 19, Train/Test Score: 0.964/0.961
#           train     test
# depth
# 1      0.930320  0.92844
# 3      0.972107  0.97116
# 5      0.972107  0.97116
# 7      0.972107  0.97116
# 9      0.972120  0.97120
# 11     0.972867  0.97112
# 13     0.974507  0.97148
# 15     0.977053  0.97160
# 17     0.981280  0.97128
# 19     0.986933  0.97088
# 21     0.993293  0.97096
# 23     0.997520  0.97028
# 25     0.998947  0.97012
# 27     0.999253  0.96968
# 29     0.999307  0.96944
# 31     0.999267  0.97008
# 33     0.999280  0.97004
# 35     0.999293  0.96992
# 37     0.999293  0.96960
# 39     0.999307  0.97004
# ...
